# %%
import requests

base_url = "https://amp-api.dpgdatalake.kr/api/call"

token_5 = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJtZW1iZXJfaWQiOiIwMDAwMDAxNSIsInVzZXJfaWQiOiJkcGdoYWNrMDUifQ.58FUpd3QwECO1LqA-HL8hXXGc_3mwYCctqhTHS0XMsE"

query_value = """
follow below proccess:
Q: 월 200만원 월급으로 1000만원 모으고 싶어요
A:
1.
- 매달 40만원
- 연 이자율: 3%
- 12개월
- 월 이자율: \( r = \frac{0.03}{12} = 0.0025 \)

적금 만기 금액 \( A_1 \)

\[
A_1 = P \times \frac{(1 + r)^n - 1}{r} \times (1 + r)
\]

- \( P = 400,000 \) (매월 저축 금액)
- \( r = 0.0025 \) (월 이자율)
- \( n = 12 \) (개월 수)

\[
A_1 = 400,000 \times \frac{(1 + 0.0025)^{12} - 1}{0.0025} \times (1 + 0.0025) \approx 4,878,719
\]

---

2.
첫 번째 적금 만기 금액 \( A_1)을 연 3%의 예금으로 예치합니다.

최종 금액 \( E \)
\[
E = A_1 \times (1 + 0.03) = 4,878,719 \times 1.03 \approx 5,025,080
\]

---

3.
첫 번째 적금 만기 후, 다시 매달 40만원씩 1년 동안 적금을 넣습니다.

두 번째 적금 만기 금액 \( A_2 \)
\[
A_2 = 400,000 \times \frac{(1 + 0.0025)^{12} - 1}{0.0025} \times (1 + 0.0025) \approx 4,878,719
\]

---

4.

\[
\text{최종 금액} = E + A_2 = 5,025,080 + 4,878,719 \approx 9,903,799
\]

---

Q: 월 500만원 월급으로 1000만원 모으고 싶어요.
A:
"""

query_value = """System Prompt
: 당신은 친절한 금융 전문가입니다.
Q: {월급}, {실수령액}, {공제액계}, {국민연금}, {건강보험}, {장기요양}, {고용보험},{소득세}, {지방소득세}, {직장연차}
저에게 적절한 {is_diposit} 상품을 추천해주세요.
A: 사용자님께 추천해드릴 {is_diposit} 상품은 {kor_co_nm}의 {fin_prdt_nm}입니다. 해당 상품은 {rate}의 높은 금리와, {summation}라는 점에서 추천합니다.
그리고 고객님의 {고객정보}와 같은 상황에 {fin_prdt_info}가 {benefit} 정도의 이득이 있습니다.
가입 전에 {etc}과 같은 특이사항이 있으니 확인하시기 바랍니다.
Q: {250만원}, {2248340}, {251660}, {108,000}, {74880}, {5520}, {15600},{43330}, {4330}, {11개월}
저에게 적절한 예금 상품을 추천해주세요.
A:
"""

query_value = """
당신은 친절한 금융 전문가입니다. 당신의 역할은 주어진 정보를 바탕으로 사용자에게 작절한  금융 상품을 추천하는 것입니다. {fin_prdt_cd}이 같은 optionList를 찾아 다양한 정보를 비교하세요.
Q: info: {금액}, {기간}
저에게 적절한 {is_deopsit} 상품을 추천해주세요.
A: {금액}과 {기간}에 따라 추천드릴 {is_deposit} 상품은 {kor_co_nm}의 {fin_prdt_nm}입니다. 해당 상품은 {intr_rate}의 금리를 가지고 있으며, {fin_prdt-_summation}과 같은 특징을 가지고 있어 사용자님에게 적절하다고 판단됩니다.
{intr_rate}의 이자율을 가지고 있습니다.
가입 전에 {etc_note}과 같은 특이사항이 있으니 확인하시기 바랍니다.
Q: info: {금액:3000만원, 기간:3년}
저에게 적절한 예금 상품을 추천해주세요.
"""

url = f"{base_url}/{token_5}"
params = {"query": query_value}

# GET 요청 보내기
response = requests.get(url, params=params)

# 응답 출력
print(response.json()['ai_answer'])
